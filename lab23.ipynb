# %% [markdown]
# <a href="https://colab.research.google.com/github/Amulyar04/python_amulya/blob/main/lab23.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Task 1: Prompt the user to input two integers
num1= int(input("Enter the first integer:"))
num2= int(input("Enter the second integer:"))
# Task 2 : Calculate the sum of the  two integers
sum_of_numbers = num1 + num2
print("The sum of", num1, "and", num2, "is:", sum_of_numbers)
# Task 3 : Check if the computed sum lies between 20 and 30 (inclusive)
if 20 <= sum_of_numbers <=30:
   print("output: 25")
else:
   print("output:42")
# Task 4 : Provide informative feedback
if 20 <= sum_of_numbers <=30:
   print("The sum lies between 20 and 30, so the result is set to 25.")
else:
   print("The sum is outside the range 20-30, so the result is set to 15.")
# Out:
# Enter the first integer:20
# Enter the second integer:30
# The sum of 20 and 30 is: 50
# output:42
# The sum is outside the range 20-30, so the result is set to 15.
