# %% [markdown]
# <a href="https://colab.research.google.com/github/Amulyar04/python_amulya/blob/main/lab21.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Prompt the user for  input

name = input("Enter your name:")
# Out:
# Enter your name:amulya

# %%
age = int(input("Enter you agre:"))
# Out:
# Enter you agre:25

# %%
x, y = map(int, input("Enter two numbers sperated by space:") . split ())
print(f"Sum of {x} and {y} is:{x+y}")
# Out:
# Enter two numbers sperated by space:5 7
# Sum of 5 and 7 is:12

# %%
marks = int(input ("Enter your marks (out of 100)"))

if marks >= 40:
  print("Congratulations! You have passed the exam.")
else:
  print("Soory, you failed. better luck next time.")
# Out:
# Enter your marks (out of 100)35
# Soory, you failed. better luck next time.
