# %% [markdown]
# <a href="https://colab.research.google.com/github/Amulyar04/python_amulya/blob/main/lab20.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Implementation of special operators in python
# Identify Comparisions
x = [2,3,4]
y = [2,3,4]
z = x

print(f"x is y: {x is y}") # False, x and y are different objects
print(f"x is z: {x is z}") # True, x and  z refer to the same objects
print(f"x is not y: {x is not y}") # True, x and y are different objects
print(f"x is not z: {x is not z}") # false, x and z refer to same objects

# Membership Operators
numbers = [10,20,30,40]
value = 30
value_not_in = 50

# Membership Checks
print(f"{value} in sequence: {value in numbers}")
print(f"{value_not_in} in sequqnce: {value_not_in in numbers}")
print(f"{value} not in sequnce: {value not in numbers}")
print(f"{value_not_in} not in sequnce: {value_not_in not in numbers}")
# Out:
# x is y: False
# x is z: True
# x is not y: True
# x is not z: False
# 30 in sequence: True
# 50 in sequqnce: False
# 30 not in sequnce: False
# 50 not in sequnce: True
